# %% [markdown]
# <a href="https://colab.research.google.com/github/csap7/ictiitk/blob/master/ai1_19062019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import pandas as pd
import urllib.request

# %%
hnames = ['sepal-length','sepal-width','petal-length','petal-width','class']

# %%
web_path = urllib.request.urlopen("http://goo.gl/QnHW4g")

# %%
df = pd.read_csv(web_path,names=hnames)
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.hist()
plt.show()

# %%
df.plot(kind='density', subplots=True, layout=(2,2), sharex=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7e91ccba20>,
# ...
#       dtype=object)
